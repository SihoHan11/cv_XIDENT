# %%
from jsonNormalizeYolo import run_conversion

# Training 데이터 변환 시작
run_conversion('Training')

# Validation 데이터 변환 시작
run_conversion('Validation')
# Out:
# [작업 시작] Training 데이터 세트: 328011개
# Training 변환 중: 100%|██████████| 328011/328011 [07:46<00:00, 702.91it/s]
# [Training 작업 요약]
# - 신규 생성: 186654개
# - 이미 존재: 141355개
# - 객체 없음(스킵): 0개
# - 오류 발생: 1개
#
# [작업 시작] Validation 데이터 세트: 41526개
# Validation 변환 중: 100%|██████████| 41526/41526 [01:06<00:00, 624.05it/s]
# [Validation 작업 요약]
# - 신규 생성: 23514개
# - 이미 존재: 18010개
# - 객체 없음(스킵): 0개
# - 오류 발생: 2개
