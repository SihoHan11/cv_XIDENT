# %%
from checkDistribution import run_analysis

run_analysis()
# Out:
# [dataset] Total label files found: 0
# Analyzing dataset labels: 0it [00:00, ?it/s]
# [ dataset Class Distribution ]
# Class 0 (eye_opened): 0
# Class 1 (eye_closed): 0
# Class 2 (mouth_opened): 0
# Class 3 (mouth_closed): 0
# Class 4 (face): 0
#
# Checking image-label matching in C:\workspace\cv\dataset...
# Matching dataset: 0it [00:00, ?it/s]
# ...
#
# All images have matching label files.
